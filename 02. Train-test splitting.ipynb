# %%
import os
import numpy as np
import pickle
from utils import utils_gn, utils_dgrd
import importlib
importlib.reload(utils_gn)
importlib.reload(utils_dgrd)
# Out:
# <module 'utils.utils_dgrd' from '/home/s2228293/Documents/MACMIGS-Year2/Semester1/CCDV-project/utils/utils_dgrd.py'>

# %% [markdown]
# Here, we want to remove all cells whose cycle life is greater than 1200, a data prpcessing step. We also remove cells that belong to batches 4 to 7 as they are not considered now for modelling. Also, we will split the *raw data* into train and test sets, and dump them as pickle files. Although this might be can considered as too early, it is the best practice to carry out exploration and transformation only on the train data. This will curb *peeping into the test data*, *over-fitting* and *biasedness*.

# %%
# Load all the batches 
batch = utils_gn.read_data('data_101cycles_ir.pkl')

# %%
# Remove batteries with more than 1200 cycle life and those belong to batches 4 to 7
odd_cells = []

for cell in batch.keys():
    Qd = batch[cell]['summary']['QDischarge']
    Qd_eol = Qd >= .88   # eol is defined as cycle number at 80% of nominal capacity
    Qd = Qd[Qd_eol]
    #if np.any([len(Qd) > 1200, cell[:2] in ('b4', 'b5', 'b6', 'b7', 'b8')]):
    if np.any([len(Qd) > 1200, cell[:2] in ('b4', 'b5', 'b6', 'b7')]):
        odd_cells.append(cell) 
odd_cells
# Out:
# ['b1c0',
#  'b1c1',
#  'b1c2',
#  'b1c3',
#  'b1c4',
#  'b3c7',
#  'b3c16',
#  'b3c17',
#  'b3c33',
#  'b3c42',
#  'b3c45',
#  'b4c0',
#  'b4c1',
#  'b4c2',
#  'b4c3',
#  'b4c4',
#  'b4c5',
#  'b4c6',
#  'b4c7',
#  'b4c8',
#  'b4c9',
#  'b4c10',
#  'b4c11',
#  'b4c12',
#  'b4c13',
#  'b4c14',
#  'b4c15',
#  'b4c16',
#  'b4c17',
#  'b4c18',
#  'b4c19',
#  'b4c20',
#  'b4c21',
#  'b4c22',
#  'b4c23',
#  'b4c24',
#  'b4c25',
#  'b4c26',
#  'b4c27',
#  'b4c28',
#  'b4c29',
#  'b4c30',
#  'b4c31',
#  'b4c32',
#  'b4c33',
#  'b4c34',
#  'b4c35',
#  'b4c36',
#  'b4c37',
#  'b4c38',
#  'b4c39',
#  'b4c40',
#  'b4c41',
#  'b4c42',
#  'b4c43',
#  'b4c44',
#  'b4c45',
#  'b5c0',
#  'b5c1',
#  'b5c2',
#  'b5c3',
#  'b5c4',
#  'b5c5',
#  'b5c6',
#  'b5c7',
#  'b5c8',
#  'b5c9',
#  'b5c10',
#  'b5c11',
#  'b5c12',
#  'b5c13',
#  'b5c14',
#  'b5c15',
#  'b5c16',
#  'b5c17',
#  'b5c18',
#  'b5c19',
#  'b5c20',
#  'b5c21',
#  'b5c22',
#  'b5c23',
#  'b5c24',
#  'b5c25',
#  'b5c26',
#  'b5c27',
#  'b5c28',
#  'b5c29',
#  'b5c30',
#  'b5c31',
#  'b5c32',
#  'b5c33',
#  'b5c34',
#  'b5c35',
#  'b5c36',
#  'b5c37',
#  'b5c38',
#  'b5c39',
#  'b5c40',
#  'b5c41',
#  'b5c42',
#  'b5c43',
#  'b5c44',
#  'b5c45',
#  'b6c0',
#  'b6c1',
#  'b6c2',
#  'b6c3',
#  'b6c4',
#  'b6c5',
#  'b6c6',
#  'b6c7',
#  'b6c8',
#  'b6c9',
#  'b6c10',
#  'b6c11',
#  'b6c12',
#  'b6c13',
#  'b6c14',
#  'b6c15',
#  'b6c16',
#  'b6c17',
#  'b6c18',
#  'b6c19',
#  'b6c20',
#  'b6c21',
#  'b6c22',
#  'b6c23',
#  'b6c24',
#  'b6c25',
#  'b6c26',
#  'b6c27',
#  'b6c28',
#  'b6c29',
#  'b6c30',
#  'b6c31',
#  'b6c32',
#  'b6c33',
#  'b6c34',
#  'b6c35',
#  'b6c36',
#  'b6c37',
#  'b6c38',
#  'b6c39',
#  'b6c40',
#  'b6c41',
#  'b6c42',
#  'b6c43',
#  'b6c44',
#  'b6c45',
#  'b6c46',
#  'b6c47',
#  'b7c0',
#  'b7c1',
#  'b7c2',
#  'b7c3',
#  'b7c4',
#  'b7c5',
#  'b7c6',
#  'b7c7',
#  'b7c8',
#  'b7c9',
#  'b7c10',
#  'b7c11',
#  'b7c12',
#  'b7c13',
#  'b7c14',
#  'b7c15',
#  'b7c16',
#  'b7c17',
#  'b7c18',
#  'b7c19',
#  'b7c20',
#  'b7c21',
#  'b7c22',
#  'b7c23',
#  'b7c24',
#  'b7c25',
#  'b7c26',
#  'b7c27',
#  'b7c28',
#  'b7c29',
#  'b7c30',
#  'b7c31',
#  'b7c32',
#  'b7c33',
#  'b7c34',
#  'b7c35',
#  'b7c36',
#  'b7c37',
#  'b7c38',
#  'b7c39',
#  'b7c40',
#  'b7c41',
#  'b7c42',
#  'b7c43',
#  'b7c44',
#  'b7c45',
#  'b7c46',
#  'b7c47']

# %%
new_batch = {k: batch[k] for k in batch.keys() if k not in odd_cells}
len(new_batch.keys())
# Out:
# 158

# %%
# Split the data into 70-30% train-test and dump in a pickle file
train, test = utils_gn.split_train_test_by_id(new_batch, test_ratio=0.3)

with open(os.path.join("data", "train_1238.pkl"), "wb") as fp:
    pickle.dump(train, fp)

with open(os.path.join("data", "test_1238.pkl"), "wb") as fp:
    pickle.dump(test, fp)

# %%
# Get the true labels for the test data
true_test_labels = utils_dgrd.create_knee_elbow_data(test)
with open(os.path.join("data", "true_test_labels_1238.pkl"), "wb") as fp:
    pickle.dump(true_test_labels, fp)

# %%
# Get the true labels for the train data
true_train_labels = utils_dgrd.create_knee_elbow_data(train)
with open(os.path.join("data", "true_train_labels_1238.pkl"), "wb") as fp:
    pickle.dump(true_train_labels, fp)
